# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **(1) Name:** Adam Jones (no team members)
# **(2) Three Paragraphs:**
#     **-(i) Background:**  In an increasingly connected society, physical barriers to the spread of infections diseases are becoming fewer and fewer.  Infectious diseases such as the black plague, the H1N1 virus or SARS have negatively impacted the lives of individuals across many geographic locations.  Watching the prevalence of each disease on the world map can give one a sense of how prevalent the disease is in the world, however, it provides little information as to where the disease will spread next.  Creating a network of cities around the world and then modifying the distance between each city according to parameters related to travel, provides a way to reorganize the network in a way in which the spread of a disease resembles a wave created by dropping an object into water, allowing researchers to estimate the arrival time of infectious diseases with much greater accuracy than before.
#     **-(ii) Research Question:**  Research claims that network data is more substantial in predicting the spread of infectious disease than characteristics about the disease itself.  I wish to test this hypothesis.  At what point and for which parameters of an infectious disease will the aspects of the infectious disease dominate the dynamics of the spread of the disease?  In other words, what type of disease would it take for the model described in *The Hidden Geometry of Complex, Network-Driven Contagion Phenomena* by Dirk Brockmann and Dirk Helbing to fail to describe the spread of diseases at the level of accuracy that is described in their paper?
#     **-(iii) Anticipated Findings:**  I would think that extreme values for parameters such as the gestation period or the ease at which the disease is transmitted would affect the model described by Dirk Brockmann and Dirk Helbing.  If the gestation period is extremely long, the appearance of the disease might not closely match the initial spreading of the disease.  If the disease is extremely difficult to transmit, its spreading may be best characterized by a different network than the air traffic network shown by Dirk Brockmann and Dirk Helbing, such as a personal or social network.
# **(3) Data and/or Algorithms:**  The air travel network data from Dirk Brockmann and Dirk Helbing may be used.  Many of the algorithms outlined by Dirk Brockmann and Dirk Helbing in both their original paper, *The Hidden Geometry of Complex, Network-Driven Contagion Phenomena* and in their supplementary text will also be used.
